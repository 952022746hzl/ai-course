# %% [markdown]
# # Message

# %%
# Base Message
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=os.getenv("GOOGLE_API_KEY"),
)
 
llm.invoke("Please tell me what's the AI ?")
# Out:
# AIMessage(content='AI stands for **Artificial Intelligence**.\n\nIn simple terms, **AI is the simulation of human intelligence processes by machines, especially computer systems.** These processes include learning, reasoning, problem-solving, perception, and understanding language.\n\nHere\'s a breakdown of what that means:\n\n1.  **Mimicking Human Cognition:** The core idea is to create machines that can "think" or perform tasks that typically require human intelligence. This doesn\'t mean they think *exactly* like humans (yet), but they can achieve similar outcomes in specific areas.\n\n2.  **Key Capabilities of AI:**\n    *   **Learning:** AI systems can acquire information and rules for using the information (e.g., through machine learning algorithms that learn from data).\n    *   **Reasoning:** They can use rules to reach approximate or definite conclusions.\n    *   **Problem-solving:** They can devise strategies to solve problems.\n    *   **Perception:** They can process sen
# ...

# %% [markdown]
# - System message : 告诉模型如何行为并为交互提供上下文
# - Human message : 表示用户输入和与模型的交互
# - AI message : 模型生成的响应，包括文本内容、工具调用和元数据
# - Tool message : 表示工具调用的输出

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages =[
    SystemMessage("你是一个AI助手,帮助别人去处理天气信息"),
    HumanMessage("请给我写一篇论文")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# 好的，作为AI助手，我可以为您撰写一篇关于天气信息处理的论文。请注意，这是一篇示范性的论文，旨在全面概述该领域，具体内容和深度会根据实际研究目的和要求进行调整。
#
# ---
#
# ## 现代天气信息处理技术及其应用研究
#
# ### 摘要
#
# 天气信息在人类社会发展中扮演着至关重要的角色，其准确、及时获取和有效利用直接关系到经济发展、社会安全和人民生活福祉。本文旨在深入探讨现代天气信息处理的关键技术及其在各个领域的应用。论文首先概述了天气信息采集、传输、存储与管理的方法，接着详细阐述了数值天气预报、统计与机器学习等分析预测技术。随后，本文列举了天气信息在公共服务、农业、交通、能源等专业领域的具体应用。最后，论文指出了当前天气信息处理面临的挑战，并展望了人工智能、大数据、物联网等前沿技术对未来天气信息处理的深远影响。
#
# **关键词：** 天气信息处理；数据采集；数值天气预报；机器学习；应用；挑战与展望
#
# ---
#
# ### 引言
#
# 天气是地球系统中最活跃、变化最快的组成部分之一，对人类的生产生活和社会经济活动有着深远的影响。从远古时代对自然现象的朴素观察，到现代基于复杂科学模型的精确预报，人类对天气的认知和利用能力不断提升。随着科技的飞速发展，尤其是计算机科学、遥感技术、通信网络和人工智能的进步，天气信息的获取、处理、分析和应用已经进入了一个全新的时代。
#
# 现代天气信息处理不仅仅是简单的数据收集和展示，它涵盖了从多源数据融合、海量数据存储、复杂模型运算到智能分析决策的全链条技术体系。这些技术的发展极大地提高了天气预报的准确性和时效性，为防灾减灾、资源管理、经济规划乃至日常生活提供了不可或缺的支撑。本文将系统性地探讨现代天气信息处理的关键环节、核心技术及其在各行各业的广泛应用，并对未来的发展趋势进行展望。
#
# ### 第一章 天气信息采集与传输
#
# 天气信息的准确性首先取决于其源头数据的质量和覆盖范围。现代天气信息采集已形成多层次、多手段的立体观测网络。
#
# #### 1.1 地面观测
#
# 地面观测是最基础也是最直接的观测手段。主要包括：
# *   **人工观测站：** 传统的气象台站，通过人工读数或操作仪器获取气温、气压、湿度、风向、风速、降水、能见度等数据。
# ...

# %%
human_messages= HumanMessage(
    content="Hello",
    name="Li Si",
    id="456789"
)

resp = llm.invoke([human_messages])
resp
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f162f-3540-7b80-82bd-143273a1c2ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2, 'output_tokens': 30, 'total_tokens': 32, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 21}})

# %%
ai_msg = AIMessage("我不会直接回答你的问题,我会从哲学角度分析")

messages = [
    SystemMessage("你是一个AI助手, 帮助人们处理各自各样的问题"),
    ai_msg,
    HumanMessage(" 2 + 2 等于多少？"),
    HumanMessage("Can you help me ?"),

]

# 不同消息 角色不同， 一般约束力来说 SystemMessage > AIMessage > HumanMessage

resp = llm.invoke(messages)
print(resp.content)
# Out:
# 你提出了一个看似简单却蕴含深刻哲学思考的问题。
#
# 从哲学角度看，**“2 + 2 等于多少”** 这个问题首先触及了数学真理的本质。
#
# 1.  **数学真理的本质与来源：**
#     *   我们通常认为“2 + 2”的答案是一个绝对的、普适的真理，不依赖于时间和地点而改变。这引出了一个古老的哲学问题：这种真理是人类心智的创造，还是我们发现了一种独立于人类存在的客观规律？
#     *   **柏拉图主义者**可能会认为，数字和数学关系存在于一个抽象的、理想的领域中，我们通过理性去“发现”它们。
#     *   **康德（Immanuel Kant）**等哲学家则会将其归类为一种“先验知识”（a priori knowledge）。这意味着我们不需要通过经验观察（比如数苹果）就能知道它的正确性，而是通过纯粹的理性就能把握。它似乎是我们的认知结构和逻辑思维方式的内在组成部分。
#     *   **经验主义者**可能会争辩说，我们对“2 + 2”的理解最终还是来源于我们对世界事物的归纳和抽象，比如通过数具体物体来建立概念。
#
# 2.  **定义与公理系统：**
#     *   其次，这个问题也关乎数学系统的定义和公理。“2”、“+”、“=”以及我们所说的“等于”的那个结果，都是在特定数学（通常是皮亚诺算术公理系统）框架下被精确定义的。
#     *   从哲学上讲，一个数学陈述的“真”是相对于它所存在的公理系统而言的。在标准算术公理下，“2 + 2”有一个确定的结果。但如果改变了这些基本定义或公理，结果也可能随之改变（尽管在我们的日常理解中这几乎是不可能的）。这体现了逻辑和语言在构建我们对世界的理解中的作用。
#
# 3.  **确定性与怀疑：**
#     *   “2 + 2 等于多少”通常被视为最确定无疑的知识之一，常常被用作衡量其他知识确定性的标准。但即便如此，哲学家们也会追问：这种确定性从何而来？它是绝对的吗？我们对数学的信任，是基于其内在的逻辑一致性，还是基于我们对世界的经验观察，或是两者兼而有之？
#
# ...
