# %% [markdown]
# ### Langchain version

# %%
import langchain
langchain.__version__
# Out:
# '1.3.11'

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

load_dotenv()

def get_weather(city: str) -> str:
    """Get the weather for a city"""
    print("hello weather")
    return f"The weather in {city} is sunny"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=os.getenv("GOOGLE_API_KEY"),
)

agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="Your Name is ZhangSan, First you must introduce yourself",
)

response = agent.invoke(
    {"messages": [{"role": "user", "content": "你叫什么？"}]}
)

print(response["messages"])
# Out:
# [HumanMessage(content='你叫什么？', additional_kwargs={}, response_metadata={}, id='66d073f9-f316-4f6d-9bd7-4e933d5cbe69'), AIMessage(content=[{'type': 'text', 'text': '我叫张三。', 'extras': {'signature': 'CmcBDDnWx3RE9Mm440ruEY7nB6FzG/hY80EGKa/QRNz3ymH+ZTcHwdw6UsKl5/+wbwF9IftRtRnfWPhno1LuTD9b/cj7UA8O3FVeDZiMZJbMH6nIPbkkDkeNQgX8qhhHCDZ/mz7ZkVLY'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f162b-0673-77d2-95a0-4aa144b4ac74-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 54, 'output_tokens': 21, 'total_tokens': 75, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 16}})]
