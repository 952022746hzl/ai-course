# %% [markdown]
# ## Streaming

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent
import os

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=os.getenv("GOOGLE_API_KEY"),
)
agent = create_agent(
    model=llm
)

for chunk in llm.stream("写一篇关于深圳地产的200字文章"):
    print(chunk.content, end="", flush=True)
# Out:
# 深圳房地产市场一直是全国乃至全球关注的焦点。其高房价、高周转率和强劲需求背后，是深圳作为经济特区和科技创新中心的独特魅力。快速的人口净流入、有限的土地供应以及旺盛的财富效应，共同推高了深圳的住宅和商业地产价值。
#
# 然而，高昂的房价也带来了巨大的挑战，尤其是对年轻人才的吸引力和城市的可持续发展。为此，政府持续出台严厉的调控政策，包括限购、限贷、增加保障性住房供应等，力求市场平稳健康发展。
#
# 当前，深圳楼市在政策引导下趋于理性，交易量有所回落，但其作为核心城市的长期投资价值依然显著。未来，如何在创新发展与居住公平之间找到平衡，仍是深圳地产面临的重要课题。

# %% [markdown]
# # Batch

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent
import os

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=os.getenv("GOOGLE_API_KEY"),
)
agent = create_agent(
    model=llm
)

responses = llm.batch([
"今天深圳天气怎么样?",
"为什么鹦鹉会说话",
"什么叫走个面儿？"
],
config = {
    "max_concurrency":1 
}
)

for resp in responses:
    print(resp)
# Out:
# content='好的，为您查询深圳今天的天气情况：\n\n**目前（[当前时间，例如：上午10点]）深圳天气：**\n\n*   **气温：** 大约 **29°C**\n*   **体感温度：** 约 **33°C** (由于湿度较大)\n*   **天气状况：** **多云**\n*   **湿度：** 较高，约 75%\n*   **风力：** 微风，偏南风 2-3级\n*   **空气质量：** 良好\n\n**今天（[今天的日期]）白天和夜间天气预报：**\n\n*   **白天：** 预计以**多云间晴**为主，局部地区可能有**短时阵雨或雷阵雨**。\n    *   **最高气温：** 约 **32-33°C**\n    *   **紫外线指数：** 较高，请注意防晒。\n*   **夜间：** **多云**，有**轻微雷阵雨**的可能。\n    *   **最低气温：** 约 **27°C**\n\n**温馨提示：**\n\n*   今天深圳天气**炎热潮湿**，请注意**防暑降温**，多补充水分。\n*   外出请做好**防晒措施**，并建议**携带雨具**，以防局部阵雨。\n\n祝您在深圳度过愉快的一天！' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019f162c-1d97-7bb0-8905-6fa21a7d0aad-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 1445, 'total_tokens': 1451, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1121}}
# content='鹦鹉会“说话”是一种非常迷人的现象，但与人类真正理解语言含义的说话有所不同。它们主要是通过**模仿**来发出人类或其他动物的声音。这背后涉及多个复杂的因素：\n\n1.  **特殊的生理结构：**\n    *   **鸣管 (Syrinx)：** 这是鸟类特有的发声器官，相当于哺乳动物的喉头。鹦鹉的鸣管非常发达和灵活，拥有比许多其他鸟类更多的肌肉，这使得它们能够发出各种复杂的音调、音高和节奏，包括模仿人类语言的复杂声音。\n    *   **舌头和喉部：** 鹦鹉的舌头相对较厚和灵活，能够辅助鸣管形成不同的口腔共鸣腔，从而发出更接近人类辅音和元音的声音。\n\n2.  **高度发达的大脑和学习能力：**\n    *   **独特的发声学习区域 (Vocal Learning Regions)：** 鹦鹉的大脑中拥有专门用于声音学习和产生（称为“发声学习回路”）的区域，这些区域在结构上与其他鸟类（如鸣禽）相似，但在鹦鹉中更为发达。这使得它们能够学习、记忆和再现新的声音，而不仅仅是发出天生的叫声。\n    *   **高智商和模仿能力：** 鹦鹉是鸟类中智商较高的物种之一，它们天生具有很强的好奇心和模仿能力。它们会仔细聆听环境中的声音，并尝试复制。\n\n3.  **社会性和沟通需求：**\n    *   **群居动物：** 鹦鹉在野外是群居动物，它们通过各种叫声和鸣叫来与同伴交流，包括识别群体成员、警告捕食者、求偶等。这种强烈的社会性使得它们天生就善于通过声音进行交流。\n    *   **融入群体：** 当鹦鹉被人类饲养时，它们常常会把人类家庭视为自己的“鸟群”。为了融入这个群体，它们会尝试模仿人类的声音，因为这是一种与“同伴”建立联系和沟通的方式。当它们成功模仿并得到人类的积极回应（如奖励、关注），这种行为就会被强化。\n\n4.  **环境和训练：**\n    *   **刺激和互动：** 那些会“说话”的鹦鹉通常生活在充满人类声音的环境中，并且与人类有频繁的互动。人类的反复教导和积极反馈（例如，鹦鹉说“你好”时，主人也回应“你好”并给予食物或爱抚）会大大增强鹦鹉学习和模仿的动力。\n    *   **关联学习：** 虽然鹦鹉不理解抽象的语言含义，但它们可以通过条件反射建立声音和情境之间的关联。例如，它们学会了在有人进门时说“你好”，在有人出门时说“再见”，或者在看到某个物品时发出特定的声音。这表明它们能够理解一些情境性的联系。\n\n**总结来说，鹦鹉会“说话”是其独特的生理构造（发达的鸣管和灵活的舌头）、高度发达的大脑（特别是发声学习区域）、强烈的社会性以及后天环境刺激和训练共同作用的结果。它们是卓越的声音模仿者，通过模仿来融入环境和与“群体”进行交流，而非真正理解语言的深层含义。** 最著名的“说话”鹦鹉品种包括非洲灰鹦鹉、亚马逊鹦鹉等。' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019f162c-3c67-7152-a1ec-4080994264a6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 1931, 'total_tokens': 1937, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1185}}
# content='“**走个面儿**” (zǒu ge miànr) 是一个非常口语化、形象化的表达，意思是**去某个场合露个面、打个照面，通常是短暂的停留，主要目的是为了表示一下礼貌、尊重，或者维系人际关系，而不是为了深入参与或长时间逗留。**\n\n这里的“面儿”指的是“脸面”、“人情面子”，而不是“面条”的意思。“走个面儿”就是“去露个脸，给个面子”。\n\n**主要特点和含义：**\n\n1.  **短暂性：** 意味着你不会待太久，可能只是出现一下，打个招呼，送个祝福或慰问，然后就离开。\n2.  **礼节性/义务性：** 很多时候是出于社交礼仪、人情往来或工作需要。即使你很忙、不太想去，或者不能长时间参与，也会选择“走个面儿”，以示心意和尊重。\n3.  **维系人际关系：** 通过“露面”这个行为，让对方知道你记着他/她，重视这段关系，避免因为缺席而显得不给面子或不重视。\n4.  **象征性：** 重点在于“出现”这个行为本身，而非你具体做了什么或待了多久。\n\n**什么情况下会“走个面儿”？**\n\n*   **参加婚礼/寿宴：** 比如你和新郎新娘或寿星并不是特别亲近，或者当天有其他安排，但为了表示祝贺，你会去现场“走个面儿”，送上礼金或礼物，然后可能就先走了。\n    *   例句：“我今天晚上还有个饭局，所以去朋友婚礼就**走个面儿**，送了份礼就出来了。”\n*   **参加公司年会/活动：** 即使你身体不适或有其他事情，为了表示对公司的支持和对领导同事的尊重，也会去“走个面儿”，打个招呼。\n    *   例句：“虽然我有点感冒，但公司的年终酒会我还是得去**走个面儿**。”\n*   **探望病人/吊唁：** 去医院看望生病的朋友，或者去参加葬礼，可能因为时间不便或情感上难以承受长时间，也会选择“走个面儿”，表达关心或哀悼。\n    *   例句：“听说老王住院了，我抽空去医院给他**走个面儿**。”\n*   **参加朋友的开业庆典/展览：** 为了支持朋友的新事业或作品，即使不能全程参与，也会去现场“走个面儿”，表示祝贺。\n    *   例句：“小李新店开业，我怎么样也得去给他**走个面儿**，捧捧场。”\n\n总的来说，“走个面儿”就是指在社交场合，出于礼貌、尊重或人际关系维系的需要，进行一次短暂的、象征性的露面。' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019f162c-6735-7b72-ae00-99b083751306-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 1956, 'total_tokens': 1964, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1288}}
